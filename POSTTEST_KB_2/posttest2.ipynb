# %% [markdown]
# # POSTTEST 2
# oleh [Andi Rachmad Triandika Rusli](https://github.com/andirchmd) (2109106132)

# %% [markdown]
# ## Menganalisis sebuah Dataset Tabular
#
# ---
#
# Dataset: [PRDECT-ID: Indonesian Emotion Classification | Kaggle](https://www.kaggle.com/datasets/jocelyndumlao/prdect-id-indonesian-emotion-classification/data)

# %% [markdown]
# Untuk menganalisis dataset tabular ini saya menggunakan library pandas

# %%
import pandas as pd

# %% [markdown]
# Baca dan simpan datasetnya dengan nama `df` dan data siap dianalisis

# %%
df = pd.read_csv("PRDECT-ID Dataset.csv")
pd.DataFrame(df)
# Out:
#                    Category  \
# 0     Computers and Laptops
# 1     Computers and Laptops
# 2     Computers and Laptops
# 3     Computers and Laptops
# 4     Computers and Laptops
# ...                     ...
# 5395              Household
# 5396              Household
# 5397              Household
# 5398              Household
# 5399              Household
#
#                                            Product Name  \
# 0     Wireless Keyboard i8 Mini TouchPad Mouse 2.4G ...
# 1     PAKET LISENSI WINDOWS 10 PRO DAN OFFICE 2019 O...
# 2                   SSD Midasforce 128 Gb - Tanpa Caddy
# 3     ADAPTOR CHARGER MONITOR LCD LED TV LG merek LG...
# 4     ADAPTOR CHARGER MONITOR LCD LED TV LG merek LG...
# ...                                                 ...
# 5395  PCK-01 Penjepit Barang / Pickup Tool Ver.1 Ala...
# 5396  Ultrasonic Aroma Diffuser Humidifier Colorful ...
# 5397  Ultrasonic Aroma Diffuser Humidifier Colorful ...
# ...

# %% [markdown]
# ### Ketentuan Analisis Data

# %% [markdown]
# **Analisis 1**
#
# ---
# Tampilkan rata-rata, standar deviasi, nilai minimum, nilai maksimum, Q1, Q2, dan Q3 dari attribute bertipe angka.
#
# > Dengan `describe()` kita dapat melihat nilai-nilai yang dibutuhkan dengan ketentuan diatas

# %%
df.describe()
# Out:
#               Price  Overall Rating     Number Sold  Total Review  \
# count  5.400000e+03     5400.000000     5400.000000   5400.000000
# mean   2.386961e+05        4.854389    15961.951852   2168.645556
# std    8.016337e+05        0.108259    74201.913338   2915.666035
# min    1.000000e+02        4.100000        9.000000      4.000000
# 25%    2.000000e+04        4.800000     1630.000000    576.000000
# 50%    5.990000e+04        4.900000     3794.500000   1192.000000
# 75%    1.500000e+05        4.900000     9707.000000   2582.000000
# max    1.539900e+07        5.000000  1000000.000000  24500.000000
#
#        Customer Rating
# count      5400.000000
# mean          3.087037
# std           1.766258
# min           1.000000
# 25%           1.000000
# 50%           3.000000
# 75%           5.000000
# max           5.000000

# %% [markdown]
# **Analisis 2**
#
# ---
# Tampilkan 10 record pertama dari dataset dengan attribute bertipe angka.
#
# > Menggunakan `select_dtypes(include=None, exclude=None)` untuk memberi return value sesuai dengan tipe data pada kolom tertentu yang mempunyai tipe data record yang diinginkan.
#
# Reference: [Pandas docs](https://pandas.pydata.org/docs/reference/api/pandas.DataFrame.select_dtypes.html)

# %%
df.select_dtypes(include='number').head(10)
# Out:
#     Price  Overall Rating  Number Sold  Total Review  Customer Rating
# 0   53500             4.9         5449          2369                5
# 1   72000             4.9         2359          1044                5
# 2  213000             5.0        12300          3573                5
# 3   55000             4.7         2030           672                5
# 4   55000             4.7         2030           672                5
# 5   55000             4.7         2030           672                5
# 6   85000             4.9         1339           718                5
# 7  136500             5.0         1201           632                5
# 8  136500             5.0         1201           632                5
# 9  113777             4.9         1630           777                5

# %% [markdown]
# **Analisis 3**
#
# ---
# * Menampilkan informasi jumlah record, jumlah attribute, nama attribute, jumlah attribute dengan tipe angka.
# * Masukkan informasi tersebut dalam dictionary dengan key sesuai nama informasinya.
# * Tampilkan isi dari dictionary tersebut sebagus mungkin

# %%
angka = df.select_dtypes(include=['number'])

# buat dictionarynya
info_dict = {
    'Jumlah Record': len(df),
    'Jumlah Attribute': len(df.columns),
    'Nama Attribute': df.columns.tolist(),
    'Jumlah Attribute Angka': len(angka.columns)
}

# tampilkan dictionary
print("="*45)
print(" "*14+"Informasi Dataset")
print("="*45)
for key, value in info_dict.items():
    if isinstance(value, list): ## jika isi value == list
        value ='\n                         '.join(map(str, value)) ## mengubah list menjadi string dan pisahkan dengan \n dan spasi
        print(f"{key:<23}: {value}")
    else:
        print(f"{key:<23}: {value}")
print("=" * 45)
# Out:
# ...
#               Informasi Dataset
# ...
# Jumlah Record          : 5400
# Jumlah Attribute       : 11
# Nama Attribute         : Category
#                          Product Name
#                          Location
#                          Price
#                          Overall Rating
#                          Number Sold
#                          Total Review
#                          Customer Rating
#                          Customer Review
#                          Sentiment
#                          Emotion
# Jumlah Attribute Angka : 5
# ...

# %% [markdown]
# **Analisis 4**
#
# ---
# Menampilkan nilai dataset pada baris dimulai dengan 3 digit NIM akhir hingga data terakhir dan kolom ke 4 hingga kolom terakhir menggunakan ke 2 metode slice
#
# > Analisis ini dapat dilakukan menggunakan `iloc` dengan metode slicing yang dimana jika `[x:]` yang berarti mulai dari value x sampai akhir
#
# Reference:
# *   [iloc docs](https://pandas.pydata.org/docs/reference/api/pandas.DataFrame.iloc.html#pandas.DataFrame.iloc)
# *   [slicing docs](https://www.w3schools.com/python/python_strings_slicing.asp)

# %%
df.iloc[132:, 3:]
# Out:
#       Price  Overall Rating  Number Sold  Total Review  Customer Rating  \
# 132   85000             4.9         7834          4099                5
# 133   85000             4.9         7834          4099                5
# 134   82500             4.9        35900          6630                5
# 135   82500             4.9        35900          6630                5
# 136   82500             4.9        35900          6630                5
# ...     ...             ...          ...           ...              ...
# 5395  35000             4.9         1431           562                5
# 5396  99000             4.9        15529          4074                5
# 5397  99000             4.9        15529          4074                5
# 5398  99000             4.9        15529          4074                5
# 5399  14400             4.9         4765          3044                5
#
#                                         Customer Review Sentiment Emotion
# ...

# %% [markdown]
# **Analisis 5**
#
# ---
# Menampilkan jumlah nilai dari semua attribute yang bernilai object
#
# > Fungsi `.nunique()` berguna untuk menghitung jumlah nilai unik pada objek yang memiliki nilai berbeda dan mengabaikan nilai duplikat.
#
# reference: [nunique docs ](https://pandas.pydata.org/docs/reference/api/pandas.DataFrame.nunique.html)

# %%
objek = df.select_dtypes(include=['object'])
jumlah = objek.nunique()

table = pd.DataFrame({
    'Nama Atribut': jumlah.index,
    'Total Nilai': jumlah.values})

display(table)
# Out:
#       Nama Atribut  Total Nilai
# 0         Category           29
# 1     Product Name         1308
# 2         Location           61
# 3  Customer Review         5305
# 4        Sentiment            2
# 5          Emotion            5
